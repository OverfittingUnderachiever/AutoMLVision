# %%
import numpy as np
import matplotlib.pyplot as plt
from ft_testfunction import global_1D,local_1D

# %%
x_space=np.linspace(1, 5, 100).reshape(-1,1)
# x_space=np.append(x_space,x_space,axis=1)
print(x_space)
y_space=global_1D(x_space)
print(y_space)

plt.ylim(-0.1, 1.1)
plt.plot(x_space, y_space)
# Out:
# [[1.        ]
#  [1.04040404]
#  [1.08080808]
#  [1.12121212]
#  [1.16161616]
#  [1.2020202 ]
#  [1.24242424]
#  [1.28282828]
#  [1.32323232]
#  [1.36363636]
#  [1.4040404 ]
#  [1.44444444]
#  [1.48484848]
#  [1.52525253]
#  [1.56565657]
#  [1.60606061]
#  [1.64646465]
#  [1.68686869]
#  [1.72727273]
#  [1.76767677]
#  [1.80808081]
#  [1.84848485]
#  [1.88888889]
#  [1.92929293]
#  [1.96969697]
#  [2.01010101]
#  [2.05050505]
#  [2.09090909]
#  [2.13131313]
#  [2.17171717]
#  [2.21212121]
#  [2.25252525]
#  [2.29292929]
#  [2.33333333]
#  [2.37373737]
#  [2.41414141]
#  [2.45454545]
#  [2.49494949]
#  [2.53535354]
#  [2.57575758]
#  [2.61616162]
#  [2.65656566]
#  [2.6969697 ]
#  [2.73737374]
#  [2.77777778]
#  [2.81818182]
#  [2.85858586]
#  [2.8989899 ]
#  [2.93939394]
#  [2.97979798]
#  [3.02020202]
#  [3.06060606]
#  [3.1010101 ]
#  [3.14141414]
#  [3.18181818]
#  [3.22222222]
#  [3.26262626]
#  [3.3030303 ]
#  [3.34343434]
#  [3.38383838]
#  [3.42424242]
#  [3.46464646]
# ...

# %%
x_localspace=np.linspace(0, 100, 100)
for x_global in x_space:

    y_local=local_1D(x_global,x_localspace,noise=0.01)
    print(y_local[1])
    plt.plot(x_localspace, y_local)
    plt.scatter([100], global_1D(x_global), color='red',s=20)
# Out:
# 0.95
# 0.93
# 0.92
# 0.94
# 0.94
# 0.94
# 0.95
# 0.96
# 0.96
# 0.98
# 0.97
# 0.97
# 0.97
# 0.94
# 0.95
# 0.95
# 0.93
# 0.93
# 0.9
# 0.92
# 0.94
# 0.96
# 0.95
# 0.96
# 0.96
# 0.96
# 0.97
# 0.99
# 0.94
# 0.94
# 0.93
# 0.92
# 0.92
# 0.93
# 0.91
# 0.91
# 0.93
# 0.94
# 0.94
# 0.95
# 0.96
# 0.97
# 0.94
# 0.95
# 0.94
# 0.94
# 0.93
# 0.91
# 0.91
# 0.92
# 0.91
# 0.9
# 0.93
# 0.93
# 0.94
# 0.94
# 0.96
# 0.95
# 0.96
# 0.95
# 0.94
# 0.94
# 0.93
# 0.91
# 0.91
# 0.93
# 0.91
# 0.92
# 0.93
# 0.94
# 0.96
# 0.96
# 0.96
# 0.98
# 0.98
# 0.97
# 0.94
# 0.94
# 0.93
# 0.93
# 0.91
# 0.93
# 0.93
# 0.93
# 0.97
# 0.97
# 0.97
# 0.97
# 0.97
# 0.98
# 0.97
# 0.97
# 0.96
# 0.96
# 0.95
# 0.95
# 0.94
# 0.97
# 0.97
# 0.98
